# %%
import pandas as pd

import os
import pymongo
from pymongo.errors import AutoReconnect
import time
from dotenv import load_dotenv

# %%
df = pd.read_csv("depression.csv")
df.head(10)
# Out:
#    age  gender  sleep_quality_index  brain_fog_level  physical_pain_score  \
# 0   56    Male                  8.7              3.9                  9.2
# 1   69    Male                  1.3              9.9                  4.2
# 2   46  Female                  4.0              5.4                  4.8
# 3   32  Female                  9.4              2.1                  2.9
# 4   60  Female                  7.6              7.5                  6.4
# 5   25  Female                  3.5              3.9                  6.4
# 6   38  Female                  3.3             10.0                  4.3
# 7   56    Male                  1.0              9.8                  4.0
# 8   36  Female                  7.3              6.9                  9.0
# 9   40  Female                  1.4              2.2                  4.4
#
#    stress_level  depression_phq9_score  fatigue_severity_scale_score  \
# 0           8.1                   10.0                           6.5
# 1           9.9                   20.0                           7.0
# 2           NaN                   24.0                           1.6
# 3           3.8                   10.0                           6.8
# 4           8.5                   17.0                           7.0
# 5           6.5                    9.0                           7.5
# 6           6.2                   15.0                           7.0
# 7           3.3                   10.0                           4.5
# 8           7.8                    9.0                           7.0
# 9           1.7                    9.0                           9.8
#
#    pem_duration_hours  hours_of_sleep_per_night  pem_present  \
# 0                 9.0                       7.7            0
# 1                41.0                       8.4            1
# 2                13.0                       6.9            0
# 3                11.0                       7.5            0
# 4                46.0                       3.1            1
# 5                41.0                       4.1            1
# 6                29.0                       9.9            1
# 7                31.0                       3.5            0
# 8                31.0                       7.8            1
# 9                41.0                       4.2            1
#
#          work_status social_activity_level exercise_frequency  \
# 0            Working                   Low              Daily
# 1            Working                   Low              Often
# 2  Partially working                   NaN             Rarely
# 3        Not working                  High              Never
# 4        Not working                   Low             Rarely
# 5  Partially working                Medium              Never
# 6        Not working              Very low          Sometimes
# 7        Not working             Very high              Daily
# 8            Working                  High                NaN
# 9  Partially working                Medium             Rarely
#
#   meditation_or_mindfulness   diagnosis
# 0                       Yes  Depression
# 1                       Yes        Both
# 2                       Yes  Depression
# 3                       Yes  Depression
# 4                        No        Both
# 5                        No      ME/CFS
# 6                       Yes        Both
# 7                       Yes  Depression
# 8                        No      ME/CFS
# 9                       Yes      ME/CFS

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'sleep_quality_index', 'brain_fog_level',
#        'physical_pain_score', 'stress_level', 'depression_phq9_score',
#        'fatigue_severity_scale_score', 'pem_duration_hours',
#        'hours_of_sleep_per_night', 'pem_present', 'work_status',
#        'social_activity_level', 'exercise_frequency',
#        'meditation_or_mindfulness', 'diagnosis'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'age': 56,
#   'gender': 'Male',
#   'sleep_quality_index': 8.7,
#   'brain_fog_level': 3.9,
#   'physical_pain_score': 9.2,
#   'stress_level': 8.1,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.5,
#   'pem_duration_hours': 9.0,
#   'hours_of_sleep_per_night': 7.7,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 69,
#   'gender': 'Male',
#   'sleep_quality_index': 1.3,
#   'brain_fog_level': 9.9,
#   'physical_pain_score': 4.2,
#   'stress_level': 9.9,
#   'depression_phq9_score': 20.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 41.0,
#   'hours_of_sleep_per_night': 8.4,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 46,
#   'gender': 'Female',
#   'sleep_quality_index': 4.0,
#   'brain_fog_level': 5.4,
#   'physical_pain_score': 4.8,
#   'stress_level': nan,
#   'depression_phq9_score': 24.0,
#   'fatigue_severity_scale_score': 1.6,
#   'pem_duration_hours': 13.0,
#   'hours_of_sleep_per_night': 6.9,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': nan,
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 32,
#   'gender': 'Female',
#   'sleep_quality_index': 9.4,
#   'brain_fog_level': 2.1,
#   'physical_pain_score': 2.9,
#   'stress_level': 3.8,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.8,
#   'pem_duration_hours': 11.0,
#   'hours_of_sleep_per_night': 7.5,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 60,
#   'gender': 'Female',
#   'sleep_quality_index': 7.6,
#   'brain_fog_level': 7.5,
#   'physical_pain_score': 6.4,
#   'stress_level': 8.5,
#   'depression_phq9_score': 17.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 46.0,
#   'hours_of_sleep_per_night': 3.1,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 25,
#   'gender': 'Female',
#   'sleep_quality_index': 3.5,
#   'brain_fog_level': 3.9,
#   'physical_pain_score': 6.4,
#   'stress_level': 6.5,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.5,
#   'pem_duration_hours': 41.0,
#   'hours_of_sleep_per_night': 4.1,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 38,
#   'gender': 'Female',
#   'sleep_quality_index': 3.3,
#   'brain_fog_level': 10.0,
#   'physical_pain_score': 4.3,
#   'stress_level': 6.2,
#   'depression_phq9_score': 15.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 29.0,
#   'hours_of_sleep_per_night': 9.9,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 56,
#   'gender': 'Male',
#   'sleep_quality_index': 1.0,
#   'brain_fog_level': 9.8,
#   'physical_pain_score': 4.0,
#   'stress_level': 3.3,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 4.5,
#   'pem_duration_hours': 31.0,
#   'hours_of_sleep_per_night': 3.5,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 36,
#   'gender': 'Female',
#   'sleep_quality_index': 7.3,
#   'brain_fog_level': 6.9,
#   'physical_pain_score': 9.0,
#   'stress_level': 7.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 31.0,
#   'hours_of_sleep_per_night': 7.8,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': nan,
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 40,
#   'gender': 'Female',
#   'sleep_quality_index': 1.4,
#   'brain_fog_level': 2.2,
#   'physical_pain_score': 4.4,
#   'stress_level': 1.7,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 9.8,
#   'pem_duration_hours': 41.0,
#   'hours_of_sleep_per_night': 4.2,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 28,
#   'gender': 'Female',
#   'sleep_quality_index': 5.8,
#   'brain_fog_level': 7.2,
#   'physical_pain_score': 5.4,
#   'stress_level': 9.3,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': nan,
#   'pem_duration_hours': 31.0,
#   'hours_of_sleep_per_night': 8.0,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 28,
#   'gender': 'Male',
#   'sleep_quality_index': 9.7,
#   'brain_fog_level': 1.8,
#   'physical_pain_score': 3.5,
#   'stress_level': 3.9,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 25.0,
#   'hours_of_sleep_per_night': 7.9,
#   'pem_present': 1,
#   'work_status': nan,
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 41,
#   'gender': 'Female',
#   'sleep_quality_index': 2.0,
#   'brain_fog_level': 1.3,
#   'physical_pain_score': 8.1,
#   'stress_level': 2.1,
#   'depression_phq9_score': 2.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 0.0,
#   'hours_of_sleep_per_night': 4.6,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 70,
#   'gender': 'Female',
#   'sleep_quality_index': 9.1,
#   'brain_fog_level': 8.4,
#   'physical_pain_score': 4.6,
#   'stress_level': 5.0,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 41.0,
#   'hours_of_sleep_per_night': 4.9,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 53,
#   'gender': 'Male',
#   'sleep_quality_index': 9.9,
#   'brain_fog_level': 2.9,
#   'physical_pain_score': 5.6,
#   'stress_level': 1.4,
#   'depression_phq9_score': 7.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 1.0,
#   'hours_of_sleep_per_night': 7.6,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 57,
#   'gender': 'Female',
#   'sleep_quality_index': 1.6,
#   'brain_fog_level': 4.4,
#   'physical_pain_score': 3.3,
#   'stress_level': 7.2,
#   'depression_phq9_score': 26.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 16.0,
#   'hours_of_sleep_per_night': 5.7,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 41,
#   'gender': 'Male',
#   'sleep_quality_index': 8.9,
#   'brain_fog_level': 9.8,
#   'physical_pain_score': 9.9,
#   'stress_level': 9.1,
#   'depression_phq9_score': 25.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 29.0,
#   'hours_of_sleep_per_night': 4.4,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 20,
#   'gender': 'Male',
#   'sleep_quality_index': 5.6,
#   'brain_fog_level': 4.0,
#   'physical_pain_score': 3.6,
#   'stress_level': 8.5,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 9.0,
#   'pem_duration_hours': 38.0,
#   'hours_of_sleep_per_night': 8.1,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 39,
#   'gender': 'Male',
#   'sleep_quality_index': 9.2,
#   'brain_fog_level': 3.7,
#   'physical_pain_score': 7.9,
#   'stress_level': 2.1,
#   'depression_phq9_score': 11.0,
#   'fatigue_severity_scale_score': 1.0,
#   'pem_duration_hours': 6.0,
#   'hours_of_sleep_per_night': 4.1,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 70,
#   'gender': 'Male',
#   'sleep_quality_index': 6.1,
#   'brain_fog_level': 9.3,
#   'physical_pain_score': 4.8,
#   'stress_level': 2.1,
#   'depression_phq9_score': 1.0,
#   'fatigue_severity_scale_score': nan,
#   'pem_duration_hours': 26.0,
#   'hours_of_sleep_per_night': 9.0,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 19,
#   'gender': 'Male',
#   'sleep_quality_index': 7.0,
#   'brain_fog_level': 2.0,
#   'physical_pain_score': 2.9,
#   'stress_level': 8.3,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 8.0,
#   'hours_of_sleep_per_night': 6.6,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 41,
#   'gender': 'Female',
#   'sleep_quality_index': 5.9,
#   'brain_fog_level': 7.8,
#   'physical_pain_score': 8.2,
#   'stress_level': 9.3,
#   'depression_phq9_score': 11.0,
#   'fatigue_severity_scale_score': nan,
#   'pem_duration_hours': 21.0,
#   'hours_of_sleep_per_night': 3.7,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 61,
#   'gender': 'Male',
#   'sleep_quality_index': 8.8,
#   'brain_fog_level': 9.9,
#   'physical_pain_score': 4.0,
#   'stress_level': 5.1,
#   'depression_phq9_score': 27.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 33.0,
#   'hours_of_sleep_per_night': 7.9,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 47,
#   'gender': 'Male',
#   'sleep_quality_index': 7.6,
#   'brain_fog_level': 9.1,
#   'physical_pain_score': 8.8,
#   'stress_level': 5.5,
#   'depression_phq9_score': 17.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 45.0,
#   'hours_of_sleep_per_night': 6.6,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 55,
#   'gender': 'Female',
#   'sleep_quality_index': 5.7,
#   'brain_fog_level': 6.9,
#   'physical_pain_score': 9.2,
#   'stress_level': 3.9,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 0.0,
#   'hours_of_sleep_per_night': 5.1,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 19,
#   'gender': 'Male',
#   'sleep_quality_index': 8.8,
#   'brain_fog_level': 3.8,
#   'physical_pain_score': nan,
#   'stress_level': 9.0,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.8,
#   'pem_duration_hours': 8.0,
#   'hours_of_sleep_per_night': 6.0,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 38,
#   'gender': 'Female',
#   'sleep_quality_index': 3.2,
#   'brain_fog_level': 3.3,
#   'physical_pain_score': 1.3,
#   'stress_level': 6.8,
#   'depression_phq9_score': 21.0,
#   'fatigue_severity_scale_score': 3.0,
#   'pem_duration_hours': 19.0,
#   'hours_of_sleep_per_night': 5.1,
#   'pem_present': 0,
#   'work_status': nan,
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 50,
#   'gender': 'Female',
#   'sleep_quality_index': 2.4,
#   'brain_fog_level': 8.4,
#   'physical_pain_score': 8.1,
#   'stress_level': 3.6,
#   'depression_phq9_score': 11.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 18.0,
#   'hours_of_sleep_per_night': 4.8,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 29,
#   'gender': 'Female',
#   'sleep_quality_index': 2.4,
#   'brain_fog_level': 8.9,
#   'physical_pain_score': nan,
#   'stress_level': 3.7,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 35.0,
#   'hours_of_sleep_per_night': 4.1,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 39,
#   'gender': 'Male',
#   'sleep_quality_index': 4.0,
#   'brain_fog_level': 5.7,
#   'physical_pain_score': 8.9,
#   'stress_level': 9.0,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 0.9,
#   'pem_duration_hours': 39.0,
#   'hours_of_sleep_per_night': 5.5,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 61,
#   'gender': 'Male',
#   'sleep_quality_index': 3.1,
#   'brain_fog_level': 3.2,
#   'physical_pain_score': 6.7,
#   'stress_level': 1.1,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 44.0,
#   'hours_of_sleep_per_night': 4.8,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 42,
#   'gender': 'Male',
#   'sleep_quality_index': 9.4,
#   'brain_fog_level': 2.0,
#   'physical_pain_score': 8.5,
#   'stress_level': 3.9,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 3.0,
#   'hours_of_sleep_per_night': 7.8,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 66,
#   'gender': 'Female',
#   'sleep_quality_index': 2.0,
#   'brain_fog_level': 1.8,
#   'physical_pain_score': 5.5,
#   'stress_level': 6.0,
#   'depression_phq9_score': 25.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 8.0,
#   'hours_of_sleep_per_night': 7.8,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 44,
#   'gender': 'Male',
#   'sleep_quality_index': 7.3,
#   'brain_fog_level': 7.5,
#   'physical_pain_score': 5.8,
#   'stress_level': 2.3,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 40.0,
#   'hours_of_sleep_per_night': 6.5,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 59,
#   'gender': 'Male',
#   'sleep_quality_index': 2.7,
#   'brain_fog_level': 4.8,
#   'physical_pain_score': 2.3,
#   'stress_level': 1.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 21.0,
#   'hours_of_sleep_per_night': 8.4,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 45,
#   'gender': 'Male',
#   'sleep_quality_index': 8.9,
#   'brain_fog_level': 9.1,
#   'physical_pain_score': 8.1,
#   'stress_level': 8.3,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 17.0,
#   'hours_of_sleep_per_night': 8.9,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 33,
#   'gender': 'Female',
#   'sleep_quality_index': 9.7,
#   'brain_fog_level': 7.7,
#   'physical_pain_score': 4.8,
#   'stress_level': 9.0,
#   'depression_phq9_score': 22.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 11.0,
#   'hours_of_sleep_per_night': 7.1,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 32,
#   'gender': 'Female',
#   'sleep_quality_index': 5.2,
#   'brain_fog_level': 2.7,
#   'physical_pain_score': 5.5,
#   'stress_level': nan,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 41.0,
#   'hours_of_sleep_per_night': 7.3,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': nan,
#   'diagnosis': 'Both'},
#  {'age': 64,
#   'gender': 'Male',
#   'sleep_quality_index': 8.9,
#   'brain_fog_level': 6.5,
#   'physical_pain_score': 8.1,
#   'stress_level': 9.1,
#   'depression_phq9_score': 27.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 42.0,
#   'hours_of_sleep_per_night': 5.0,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 68,
#   'gender': 'Male',
#   'sleep_quality_index': 1.0,
#   'brain_fog_level': nan,
#   'physical_pain_score': 6.4,
#   'stress_level': 6.0,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 38.0,
#   'hours_of_sleep_per_night': 9.3,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': nan,
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 61,
#   'gender': 'Male',
#   'sleep_quality_index': 8.4,
#   'brain_fog_level': 6.2,
#   'physical_pain_score': 2.8,
#   'stress_level': 8.3,
#   'depression_phq9_score': 14.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 8.0,
#   'hours_of_sleep_per_night': 3.2,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 69,
#   'gender': 'Male',
#   'sleep_quality_index': 3.1,
#   'brain_fog_level': 7.6,
#   'physical_pain_score': 6.3,
#   'stress_level': 4.5,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 8.2,
#   'pem_duration_hours': 5.0,
#   'hours_of_sleep_per_night': 5.4,
#   'pem_present': 1,
#   'work_status': nan,
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 20,
#   'gender': 'Female',
#   'sleep_quality_index': 9.2,
#   'brain_fog_level': 8.3,
#   'physical_pain_score': 4.7,
#   'stress_level': 7.0,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 18.0,
#   'hours_of_sleep_per_night': 8.1,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 54,
#   'gender': 'Female',
#   'sleep_quality_index': 1.0,
#   'brain_fog_level': 8.6,
#   'physical_pain_score': 5.2,
#   'stress_level': 9.9,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.6,
#   'pem_duration_hours': 47.0,
#   'hours_of_sleep_per_night': 3.6,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 68,
#   'gender': 'Female',
#   'sleep_quality_index': 6.0,
#   'brain_fog_level': 3.3,
#   'physical_pain_score': 1.3,
#   'stress_level': 3.0,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 46.0,
#   'hours_of_sleep_per_night': 4.3,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 24,
#   'gender': 'Female',
#   'sleep_quality_index': 7.8,
#   'brain_fog_level': 1.3,
#   'physical_pain_score': 2.9,
#   'stress_level': 4.5,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.8,
#   'pem_duration_hours': 6.0,
#   'hours_of_sleep_per_night': 7.1,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 38,
#   'gender': 'Male',
#   'sleep_quality_index': 3.3,
#   'brain_fog_level': 7.7,
#   'physical_pain_score': 3.5,
#   'stress_level': 5.3,
#   'depression_phq9_score': 19.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 15.0,
#   'hours_of_sleep_per_night': 6.9,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 26,
#   'gender': 'Male',
#   'sleep_quality_index': 2.7,
#   'brain_fog_level': 2.0,
#   'physical_pain_score': 7.4,
#   'stress_level': nan,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 4.0,
#   'hours_of_sleep_per_night': 8.2,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 56,
#   'gender': 'Male',
#   'sleep_quality_index': 1.8,
#   'brain_fog_level': nan,
#   'physical_pain_score': 1.1,
#   'stress_level': 1.7,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 15.0,
#   'hours_of_sleep_per_night': 8.7,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 35,
#   'gender': 'Female',
#   'sleep_quality_index': 3.9,
#   'brain_fog_level': 1.0,
#   'physical_pain_score': 4.7,
#   'stress_level': 8.5,
#   'depression_phq9_score': 20.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 0.0,
#   'hours_of_sleep_per_night': 3.9,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 21,
#   'gender': 'Male',
#   'sleep_quality_index': 6.0,
#   'brain_fog_level': 7.1,
#   'physical_pain_score': 9.3,
#   'stress_level': 9.8,
#   'depression_phq9_score': 13.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 36.0,
#   'hours_of_sleep_per_night': 3.1,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 42,
#   'gender': 'Female',
#   'sleep_quality_index': 2.0,
#   'brain_fog_level': 2.5,
#   'physical_pain_score': 2.0,
#   'stress_level': 4.6,
#   'depression_phq9_score': 17.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 38.0,
#   'hours_of_sleep_per_night': 7.8,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 31,
#   'gender': 'Female',
#   'sleep_quality_index': 4.4,
#   'brain_fog_level': 6.9,
#   'physical_pain_score': 5.6,
#   'stress_level': 1.8,
#   'depression_phq9_score': 14.0,
#   'fatigue_severity_scale_score': 5.7,
#   'pem_duration_hours': 18.0,
#   'hours_of_sleep_per_night': 5.1,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 67,
#   'gender': 'Male',
#   'sleep_quality_index': 1.1,
#   'brain_fog_level': 9.9,
#   'physical_pain_score': 8.1,
#   'stress_level': nan,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 8.3,
#   'pem_duration_hours': 36.0,
#   'hours_of_sleep_per_night': 7.4,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 26,
#   'gender': 'Male',
#   'sleep_quality_index': 8.4,
#   'brain_fog_level': 1.7,
#   'physical_pain_score': 9.5,
#   'stress_level': 9.0,
#   'depression_phq9_score': 23.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 16.0,
#   'hours_of_sleep_per_night': 4.1,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 43,
#   'gender': 'Male',
#   'sleep_quality_index': 2.2,
#   'brain_fog_level': 1.7,
#   'physical_pain_score': 7.7,
#   'stress_level': 5.2,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 1.6,
#   'pem_duration_hours': 25.0,
#   'hours_of_sleep_per_night': 6.3,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 70,
#   'gender': 'Female',
#   'sleep_quality_index': 3.6,
#   'brain_fog_level': 4.1,
#   'physical_pain_score': 7.5,
#   'stress_level': 3.9,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 21.0,
#   'hours_of_sleep_per_night': 6.5,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 19,
#   'gender': 'Male',
#   'sleep_quality_index': 1.2,
#   'brain_fog_level': 8.8,
#   'physical_pain_score': 8.4,
#   'stress_level': 5.3,
#   'depression_phq9_score': 27.0,
#   'fatigue_severity_scale_score': 6.7,
#   'pem_duration_hours': 7.0,
#   'hours_of_sleep_per_night': 7.1,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 37,
#   'gender': 'Female',
#   'sleep_quality_index': 4.9,
#   'brain_fog_level': 2.9,
#   'physical_pain_score': 5.0,
#   'stress_level': 3.9,
#   'depression_phq9_score': 2.0,
#   'fatigue_severity_scale_score': 9.8,
#   'pem_duration_hours': 32.0,
#   'hours_of_sleep_per_night': 6.6,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 45,
#   'gender': 'Male',
#   'sleep_quality_index': 8.6,
#   'brain_fog_level': 4.2,
#   'physical_pain_score': 8.3,
#   'stress_level': 5.4,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 9.9,
#   'pem_duration_hours': 1.0,
#   'hours_of_sleep_per_night': 6.5,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 64,
#   'gender': 'Female',
#   'sleep_quality_index': 4.5,
#   'brain_fog_level': 1.6,
#   'physical_pain_score': 1.1,
#   'stress_level': 8.7,
#   'depression_phq9_score': 15.0,
#   'fatigue_severity_scale_score': 6.9,
#   'pem_duration_hours': 29.0,
#   'hours_of_sleep_per_night': 5.3,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 24,
#   'gender': 'Female',
#   'sleep_quality_index': 2.6,
#   'brain_fog_level': 7.9,
#   'physical_pain_score': 9.3,
#   'stress_level': 6.3,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 2.4,
#   'pem_duration_hours': 46.0,
#   'hours_of_sleep_per_night': nan,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': nan,
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 61,
#   'gender': 'Male',
#   'sleep_quality_index': 7.8,
#   'brain_fog_level': 4.7,
#   'physical_pain_score': 5.0,
#   'stress_level': 7.3,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 19.0,
#   'hours_of_sleep_per_night': 3.6,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 25,
#   'gender': 'Female',
#   'sleep_quality_index': nan,
#   'brain_fog_level': 7.8,
#   'physical_pain_score': 6.0,
#   'stress_level': 4.3,
#   'depression_phq9_score': 5.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 17.0,
#   'hours_of_sleep_per_night': 6.0,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 64,
#   'gender': 'Female',
#   'sleep_quality_index': 2.6,
#   'brain_fog_level': 9.1,
#   'physical_pain_score': 3.3,
#   'stress_level': nan,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.8,
#   'pem_duration_hours': 42.0,
#   'hours_of_sleep_per_night': 5.5,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 52,
#   'gender': 'Male',
#   'sleep_quality_index': 7.9,
#   'brain_fog_level': 3.1,
#   'physical_pain_score': 7.7,
#   'stress_level': 7.0,
#   'depression_phq9_score': 3.0,
#   'fatigue_severity_scale_score': 9.1,
#   'pem_duration_hours': 9.0,
#   'hours_of_sleep_per_night': 6.6,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 31,
#   'gender': 'Female',
#   'sleep_quality_index': 9.5,
#   'brain_fog_level': 8.3,
#   'physical_pain_score': nan,
#   'stress_level': 2.1,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 23.0,
#   'hours_of_sleep_per_night': 5.1,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 34,
#   'gender': 'Male',
#   'sleep_quality_index': 2.5,
#   'brain_fog_level': 1.5,
#   'physical_pain_score': nan,
#   'stress_level': 6.2,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 3.0,
#   'hours_of_sleep_per_night': 7.8,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 53,
#   'gender': 'Female',
#   'sleep_quality_index': 7.9,
#   'brain_fog_level': 9.1,
#   'physical_pain_score': 8.5,
#   'stress_level': 3.3,
#   'depression_phq9_score': 25.0,
#   'fatigue_severity_scale_score': 4.3,
#   'pem_duration_hours': 36.0,
#   'hours_of_sleep_per_night': 9.0,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 67,
#   'gender': 'Male',
#   'sleep_quality_index': 7.4,
#   'brain_fog_level': 6.9,
#   'physical_pain_score': 2.9,
#   'stress_level': 8.2,
#   'depression_phq9_score': nan,
#   'fatigue_severity_scale_score': 4.4,
#   'pem_duration_hours': 3.0,
#   'hours_of_sleep_per_night': nan,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': nan,
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 57,
#   'gender': 'Male',
#   'sleep_quality_index': 5.3,
#   'brain_fog_level': 8.9,
#   'physical_pain_score': 8.3,
#   'stress_level': 4.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 12.0,
#   'hours_of_sleep_per_night': 4.4,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 21,
#   'gender': 'Female',
#   'sleep_quality_index': 1.5,
#   'brain_fog_level': 1.0,
#   'physical_pain_score': 8.1,
#   'stress_level': 10.0,
#   'depression_phq9_score': 20.0,
#   'fatigue_severity_scale_score': 7.6,
#   'pem_duration_hours': 24.0,
#   'hours_of_sleep_per_night': 3.8,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 19,
#   'gender': 'Female',
#   'sleep_quality_index': 1.7,
#   'brain_fog_level': 2.5,
#   'physical_pain_score': 6.7,
#   'stress_level': 1.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 9.4,
#   'pem_duration_hours': 12.0,
#   'hours_of_sleep_per_night': 7.3,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': nan,
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 23,
#   'gender': 'Female',
#   'sleep_quality_index': 8.7,
#   'brain_fog_level': 4.5,
#   'physical_pain_score': 4.4,
#   'stress_level': 8.0,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': nan,
#   'pem_duration_hours': 17.0,
#   'hours_of_sleep_per_night': 6.1,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 59,
#   'gender': 'Female',
#   'sleep_quality_index': 9.9,
#   'brain_fog_level': 4.4,
#   'physical_pain_score': 3.4,
#   'stress_level': 7.1,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 23.0,
#   'hours_of_sleep_per_night': 4.3,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 21,
#   'gender': 'Female',
#   'sleep_quality_index': 7.1,
#   'brain_fog_level': 3.0,
#   'physical_pain_score': 3.1,
#   'stress_level': 7.9,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 8.7,
#   'pem_duration_hours': 1.0,
#   'hours_of_sleep_per_night': 7.6,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 46,
#   'gender': 'Male',
#   'sleep_quality_index': nan,
#   'brain_fog_level': 4.4,
#   'physical_pain_score': 3.9,
#   'stress_level': nan,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.4,
#   'pem_duration_hours': 47.0,
#   'hours_of_sleep_per_night': 4.0,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 35,
#   'gender': 'Female',
#   'sleep_quality_index': 6.8,
#   'brain_fog_level': 2.2,
#   'physical_pain_score': 9.1,
#   'stress_level': 5.4,
#   'depression_phq9_score': 6.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 32.0,
#   'hours_of_sleep_per_night': 6.9,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 43,
#   'gender': 'Male',
#   'sleep_quality_index': 6.3,
#   'brain_fog_level': 4.7,
#   'physical_pain_score': 1.7,
#   'stress_level': 8.2,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 0.7,
#   'pem_duration_hours': 18.0,
#   'hours_of_sleep_per_night': 6.7,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 61,
#   'gender': 'Male',
#   'sleep_quality_index': 4.5,
#   'brain_fog_level': 8.2,
#   'physical_pain_score': 8.5,
#   'stress_level': 3.1,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': 2.7,
#   'pem_duration_hours': 8.0,
#   'hours_of_sleep_per_night': 8.1,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 51,
#   'gender': 'Female',
#   'sleep_quality_index': 1.6,
#   'brain_fog_level': 5.3,
#   'physical_pain_score': 4.1,
#   'stress_level': 3.0,
#   'depression_phq9_score': 22.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 27.0,
#   'hours_of_sleep_per_night': 3.4,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 27,
#   'gender': 'Male',
#   'sleep_quality_index': nan,
#   'brain_fog_level': 1.2,
#   'physical_pain_score': nan,
#   'stress_level': 6.0,
#   'depression_phq9_score': 26.0,
#   'fatigue_severity_scale_score': 6.3,
#   'pem_duration_hours': 34.0,
#   'hours_of_sleep_per_night': 9.2,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 53,
#   'gender': 'Male',
#   'sleep_quality_index': 4.3,
#   'brain_fog_level': 4.8,
#   'physical_pain_score': 8.2,
#   'stress_level': 5.7,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.2,
#   'pem_duration_hours': 38.0,
#   'hours_of_sleep_per_night': 7.9,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 31,
#   'gender': 'Male',
#   'sleep_quality_index': 8.4,
#   'brain_fog_level': 1.2,
#   'physical_pain_score': 9.0,
#   'stress_level': 3.5,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 9.0,
#   'hours_of_sleep_per_night': 4.5,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 48,
#   'gender': 'Male',
#   'sleep_quality_index': 3.3,
#   'brain_fog_level': 9.7,
#   'physical_pain_score': 4.1,
#   'stress_level': 3.7,
#   'depression_phq9_score': 7.0,
#   'fatigue_severity_scale_score': 7.2,
#   'pem_duration_hours': 0.0,
#   'hours_of_sleep_per_night': 4.3,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 65,
#   'gender': 'Female',
#   'sleep_quality_index': 1.0,
#   'brain_fog_level': 2.1,
#   'physical_pain_score': 5.2,
#   'stress_level': 3.5,
#   'depression_phq9_score': 15.0,
#   'fatigue_severity_scale_score': 0.3,
#   'pem_duration_hours': 41.0,
#   'hours_of_sleep_per_night': 6.0,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 32,
#   'gender': 'Male',
#   'sleep_quality_index': 2.4,
#   'brain_fog_level': 7.4,
#   'physical_pain_score': 4.7,
#   'stress_level': 7.9,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 20.0,
#   'hours_of_sleep_per_night': 8.7,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 25,
#   'gender': 'Female',
#   'sleep_quality_index': 5.2,
#   'brain_fog_level': 9.8,
#   'physical_pain_score': 1.1,
#   'stress_level': 6.9,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 8.0,
#   'hours_of_sleep_per_night': 8.9,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 31,
#   'gender': 'Female',
#   'sleep_quality_index': 9.5,
#   'brain_fog_level': 8.4,
#   'physical_pain_score': 3.7,
#   'stress_level': 8.5,
#   'depression_phq9_score': 24.0,
#   'fatigue_severity_scale_score': 1.5,
#   'pem_duration_hours': 46.0,
#   'hours_of_sleep_per_night': 6.6,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 40,
#   'gender': 'Male',
#   'sleep_quality_index': 1.9,
#   'brain_fog_level': 7.3,
#   'physical_pain_score': 5.1,
#   'stress_level': 9.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': nan,
#   'pem_duration_hours': 14.0,
#   'hours_of_sleep_per_night': 9.0,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 57,
#   'gender': 'Female',
#   'sleep_quality_index': 8.7,
#   'brain_fog_level': 8.6,
#   'physical_pain_score': 4.7,
#   'stress_level': 5.3,
#   'depression_phq9_score': 11.0,
#   'fatigue_severity_scale_score': 2.4,
#   'pem_duration_hours': 34.0,
#   'hours_of_sleep_per_night': 3.0,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 38,
#   'gender': 'Female',
#   'sleep_quality_index': 5.7,
#   'brain_fog_level': 9.8,
#   'physical_pain_score': 7.5,
#   'stress_level': 1.6,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 4.0,
#   'hours_of_sleep_per_night': 3.2,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 33,
#   'gender': 'Female',
#   'sleep_quality_index': 8.4,
#   'brain_fog_level': 6.6,
#   'physical_pain_score': 4.5,
#   'stress_level': 1.4,
#   'depression_phq9_score': nan,
#   'fatigue_severity_scale_score': 4.1,
#   'pem_duration_hours': 40.0,
#   'hours_of_sleep_per_night': 9.4,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 62,
#   'gender': 'Male',
#   'sleep_quality_index': 3.7,
#   'brain_fog_level': 6.0,
#   'physical_pain_score': 5.4,
#   'stress_level': 3.7,
#   'depression_phq9_score': 15.0,
#   'fatigue_severity_scale_score': 6.0,
#   'pem_duration_hours': 21.0,
#   'hours_of_sleep_per_night': 8.4,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 35,
#   'gender': 'Female',
#   'sleep_quality_index': 8.6,
#   'brain_fog_level': 6.7,
#   'physical_pain_score': nan,
#   'stress_level': 9.4,
#   'depression_phq9_score': 0.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 40.0,
#   'hours_of_sleep_per_night': 6.2,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': nan,
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 64,
#   'gender': 'Female',
#   'sleep_quality_index': 8.0,
#   'brain_fog_level': 5.8,
#   'physical_pain_score': 7.7,
#   'stress_level': 5.7,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 22.0,
#   'hours_of_sleep_per_night': 8.3,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 70,
#   'gender': 'Female',
#   'sleep_quality_index': 3.1,
#   'brain_fog_level': 6.7,
#   'physical_pain_score': 8.8,
#   'stress_level': 3.4,
#   'depression_phq9_score': 8.0,
#   'fatigue_severity_scale_score': 9.1,
#   'pem_duration_hours': 6.0,
#   'hours_of_sleep_per_night': 9.7,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 41,
#   'gender': 'Male',
#   'sleep_quality_index': 2.2,
#   'brain_fog_level': 5.0,
#   'physical_pain_score': 5.8,
#   'stress_level': 4.6,
#   'depression_phq9_score': 11.0,
#   'fatigue_severity_scale_score': 2.7,
#   'pem_duration_hours': 22.0,
#   'hours_of_sleep_per_night': 8.4,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 43,
#   'gender': 'Female',
#   'sleep_quality_index': 8.8,
#   'brain_fog_level': nan,
#   'physical_pain_score': 8.1,
#   'stress_level': 6.4,
#   'depression_phq9_score': 4.0,
#   'fatigue_severity_scale_score': 8.2,
#   'pem_duration_hours': 43.0,
#   'hours_of_sleep_per_night': 8.9,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 42,
#   'gender': 'Male',
#   'sleep_quality_index': 9.7,
#   'brain_fog_level': 2.1,
#   'physical_pain_score': 3.7,
#   'stress_level': 6.9,
#   'depression_phq9_score': 21.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': nan,
#   'hours_of_sleep_per_night': 8.3,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 62,
#   'gender': 'Male',
#   'sleep_quality_index': 1.3,
#   'brain_fog_level': 1.6,
#   'physical_pain_score': 5.9,
#   'stress_level': 2.4,
#   'depression_phq9_score': 19.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 26.0,
#   'hours_of_sleep_per_night': 4.2,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 58,
#   'gender': 'Male',
#   'sleep_quality_index': 7.6,
#   'brain_fog_level': 3.4,
#   'physical_pain_score': 4.1,
#   'stress_level': 9.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 40.0,
#   'hours_of_sleep_per_night': 8.8,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 46,
#   'gender': 'Male',
#   'sleep_quality_index': 9.2,
#   'brain_fog_level': 1.4,
#   'physical_pain_score': 4.7,
#   'stress_level': 5.9,
#   'depression_phq9_score': 27.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 5.0,
#   'hours_of_sleep_per_night': 4.4,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Rarely',
# ...
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 45,
#   'gender': 'Male',
#   'sleep_quality_index': 5.1,
#   'brain_fog_level': 4.5,
#   'physical_pain_score': 2.1,
#   'stress_level': 9.8,
#   'depression_phq9_score': 23.0,
#   'fatigue_severity_scale_score': 4.2,
#   'pem_duration_hours': 26.0,
#   'hours_of_sleep_per_night': 9.6,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 59,
#   'gender': 'Male',
#   'sleep_quality_index': 4.6,
#   'brain_fog_level': 9.4,
#   'physical_pain_score': 7.3,
#   'stress_level': 5.2,
#   'depression_phq9_score': nan,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 21.0,
#   'hours_of_sleep_per_night': 9.5,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': nan,
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 39,
#   'gender': 'Male',
#   'sleep_quality_index': 1.8,
#   'brain_fog_level': 5.9,
#   'physical_pain_score': 2.0,
#   'stress_level': 8.1,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 9.0,
#   'hours_of_sleep_per_night': 5.7,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 38,
#   'gender': 'Female',
#   'sleep_quality_index': 5.0,
#   'brain_fog_level': 9.5,
#   'physical_pain_score': 10.0,
#   'stress_level': 4.6,
#   'depression_phq9_score': nan,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 30.0,
#   'hours_of_sleep_per_night': 3.6,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 23,
#   'gender': 'Male',
#   'sleep_quality_index': 2.8,
#   'brain_fog_level': 3.0,
#   'physical_pain_score': 2.7,
#   'stress_level': 4.8,
#   'depression_phq9_score': 0.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 26.0,
#   'hours_of_sleep_per_night': 4.2,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 18,
#   'gender': 'Female',
#   'sleep_quality_index': 2.7,
#   'brain_fog_level': 7.5,
#   'physical_pain_score': 6.3,
#   'stress_level': 4.4,
#   'depression_phq9_score': 16.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 11.0,
#   'hours_of_sleep_per_night': 3.4,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 22,
#   'gender': 'Female',
#   'sleep_quality_index': 1.8,
#   'brain_fog_level': 6.6,
#   'physical_pain_score': 4.7,
#   'stress_level': 7.5,
#   'depression_phq9_score': 26.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 45.0,
#   'hours_of_sleep_per_night': 3.7,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 58,
#   'gender': 'Female',
#   'sleep_quality_index': 4.2,
#   'brain_fog_level': 7.7,
#   'physical_pain_score': 2.1,
#   'stress_level': 5.9,
#   'depression_phq9_score': 0.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 30.0,
#   'hours_of_sleep_per_night': 4.3,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 29,
#   'gender': 'Male',
#   'sleep_quality_index': 7.8,
#   'brain_fog_level': 2.9,
#   'physical_pain_score': 1.3,
#   'stress_level': 9.5,
#   'depression_phq9_score': 20.0,
#   'fatigue_severity_scale_score': 7.5,
#   'pem_duration_hours': 31.0,
#   'hours_of_sleep_per_night': 5.4,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 43,
#   'gender': 'Female',
#   'sleep_quality_index': 3.5,
#   'brain_fog_level': 7.0,
#   'physical_pain_score': 6.6,
#   'stress_level': 3.3,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 8.9,
#   'pem_duration_hours': 31.0,
#   'hours_of_sleep_per_night': 6.8,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 63,
#   'gender': 'Male',
#   'sleep_quality_index': 3.8,
#   'brain_fog_level': 5.5,
#   'physical_pain_score': 8.3,
#   'stress_level': 1.9,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.6,
#   'pem_duration_hours': 40.0,
#   'hours_of_sleep_per_night': 8.0,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 51,
#   'gender': 'Female',
#   'sleep_quality_index': 6.8,
#   'brain_fog_level': 7.7,
#   'physical_pain_score': 8.6,
#   'stress_level': 4.5,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 3.3,
#   'pem_duration_hours': 44.0,
#   'hours_of_sleep_per_night': 4.5,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 66,
#   'gender': 'Male',
#   'sleep_quality_index': 2.8,
#   'brain_fog_level': nan,
#   'physical_pain_score': 5.3,
#   'stress_level': 6.6,
#   'depression_phq9_score': 14.0,
#   'fatigue_severity_scale_score': 7.4,
#   'pem_duration_hours': 34.0,
#   'hours_of_sleep_per_night': 7.7,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 31,
#   'gender': 'Female',
#   'sleep_quality_index': 9.1,
#   'brain_fog_level': 9.0,
#   'physical_pain_score': 8.0,
#   'stress_level': 8.7,
#   'depression_phq9_score': 2.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 45.0,
#   'hours_of_sleep_per_night': 7.9,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 43,
#   'gender': 'Male',
#   'sleep_quality_index': 5.7,
#   'brain_fog_level': 1.8,
#   'physical_pain_score': 7.1,
#   'stress_level': 4.1,
#   'depression_phq9_score': 13.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 20.0,
#   'hours_of_sleep_per_night': 6.9,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': nan,
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 62,
#   'gender': 'Female',
#   'sleep_quality_index': nan,
#   'brain_fog_level': 8.3,
#   'physical_pain_score': 7.5,
#   'stress_level': 6.9,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 9.0,
#   'hours_of_sleep_per_night': 9.3,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 44,
#   'gender': 'Male',
#   'sleep_quality_index': 6.0,
#   'brain_fog_level': 8.8,
#   'physical_pain_score': 5.4,
#   'stress_level': 4.2,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 15.0,
#   'hours_of_sleep_per_night': 3.8,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 26,
#   'gender': 'Male',
#   'sleep_quality_index': nan,
#   'brain_fog_level': 8.4,
#   'physical_pain_score': 6.7,
#   'stress_level': 6.6,
#   'depression_phq9_score': 23.0,
#   'fatigue_severity_scale_score': 2.5,
#   'pem_duration_hours': 6.0,
#   'hours_of_sleep_per_night': 4.2,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 43,
#   'gender': 'Male',
#   'sleep_quality_index': 6.5,
#   'brain_fog_level': 5.6,
#   'physical_pain_score': 8.2,
#   'stress_level': 9.0,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 3.0,
#   'hours_of_sleep_per_night': 6.0,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 64,
#   'gender': 'Male',
#   'sleep_quality_index': 4.3,
#   'brain_fog_level': 4.9,
#   'physical_pain_score': 4.6,
#   'stress_level': 3.1,
#   'depression_phq9_score': 11.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 26.0,
#   'hours_of_sleep_per_night': 3.9,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 39,
#   'gender': 'Female',
#   'sleep_quality_index': 9.1,
#   'brain_fog_level': 10.0,
#   'physical_pain_score': 8.3,
#   'stress_level': 4.6,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': 8.0,
#   'pem_duration_hours': 24.0,
#   'hours_of_sleep_per_night': 7.0,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 64,
#   'gender': 'Female',
#   'sleep_quality_index': 2.5,
#   'brain_fog_level': 3.1,
#   'physical_pain_score': 6.3,
#   'stress_level': 9.9,
#   'depression_phq9_score': 25.0,
#   'fatigue_severity_scale_score': 6.3,
#   'pem_duration_hours': 30.0,
#   'hours_of_sleep_per_night': 5.8,
#   'pem_present': 0,
#   'work_status': 'Working',
#   'social_activity_level': 'High',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 47,
#   'gender': 'Male',
#   'sleep_quality_index': 5.6,
#   'brain_fog_level': 5.9,
#   'physical_pain_score': 2.5,
#   'stress_level': 8.8,
#   'depression_phq9_score': 12.0,
#   'fatigue_severity_scale_score': 2.5,
#   'pem_duration_hours': 10.0,
#   'hours_of_sleep_per_night': 5.0,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': nan,
#   'exercise_frequency': nan,
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 60,
#   'gender': 'Female',
#   'sleep_quality_index': 6.4,
#   'brain_fog_level': 7.0,
#   'physical_pain_score': 1.2,
#   'stress_level': nan,
#   'depression_phq9_score': 0.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 47.0,
#   'hours_of_sleep_per_night': 4.2,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 65,
#   'gender': 'Male',
#   'sleep_quality_index': 1.3,
#   'brain_fog_level': 7.3,
#   'physical_pain_score': 4.3,
#   'stress_level': 5.6,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 19.0,
#   'hours_of_sleep_per_night': 5.3,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Sometimes',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 34,
#   'gender': 'Male',
#   'sleep_quality_index': 4.3,
#   'brain_fog_level': nan,
#   'physical_pain_score': 5.9,
#   'stress_level': 3.6,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.6,
#   'pem_duration_hours': 35.0,
#   'hours_of_sleep_per_night': 7.3,
#   'pem_present': 0,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 43,
#   'gender': 'Female',
#   'sleep_quality_index': 7.6,
#   'brain_fog_level': 6.9,
#   'physical_pain_score': 8.6,
#   'stress_level': 5.7,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 16.0,
#   'hours_of_sleep_per_night': 7.0,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': nan,
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Both'},
#  {'age': 53,
#   'gender': 'Male',
#   'sleep_quality_index': 8.4,
#   'brain_fog_level': 8.4,
#   'physical_pain_score': 2.1,
#   'stress_level': 8.6,
#   'depression_phq9_score': 23.0,
#   'fatigue_severity_scale_score': 8.6,
#   'pem_duration_hours': 44.0,
#   'hours_of_sleep_per_night': 4.1,
#   'pem_present': 1,
#   'work_status': 'Not working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Both'},
#  {'age': 18,
#   'gender': 'Male',
#   'sleep_quality_index': nan,
#   'brain_fog_level': 1.5,
#   'physical_pain_score': 8.2,
#   'stress_level': 7.2,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 10.0,
#   'hours_of_sleep_per_night': 3.9,
#   'pem_present': 1,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Often',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 25,
#   'gender': 'Female',
#   'sleep_quality_index': 8.2,
#   'brain_fog_level': 9.2,
#   'physical_pain_score': 8.8,
#   'stress_level': 3.6,
#   'depression_phq9_score': 10.0,
#   'fatigue_severity_scale_score': 6.9,
#   'pem_duration_hours': 29.0,
#   'hours_of_sleep_per_night': 3.2,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Medium',
#   'exercise_frequency': nan,
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'},
#  {'age': 66,
#   'gender': 'Male',
#   'sleep_quality_index': 9.7,
#   'brain_fog_level': 1.3,
#   'physical_pain_score': 2.4,
#   'stress_level': 2.8,
#   'depression_phq9_score': 9.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 34.0,
#   'hours_of_sleep_per_night': nan,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'ME/CFS'},
#  {'age': 52,
#   'gender': 'Male',
#   'sleep_quality_index': 8.7,
#   'brain_fog_level': 4.2,
#   'physical_pain_score': 8.7,
#   'stress_level': 3.4,
#   'depression_phq9_score': 7.0,
#   'fatigue_severity_scale_score': 7.0,
#   'pem_duration_hours': 40.0,
#   'hours_of_sleep_per_night': 9.2,
#   'pem_present': 1,
#   'work_status': 'Working',
#   'social_activity_level': 'Very high',
#   'exercise_frequency': 'Daily',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'ME/CFS'},
#  {'age': 69,
#   'gender': 'Male',
#   'sleep_quality_index': 2.1,
#   'brain_fog_level': 1.1,
#   'physical_pain_score': 9.9,
#   'stress_level': 2.5,
#   'depression_phq9_score': 15.0,
#   'fatigue_severity_scale_score': 3.5,
#   'pem_duration_hours': 37.0,
#   'hours_of_sleep_per_night': 3.3,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Low',
#   'exercise_frequency': 'Never',
#   'meditation_or_mindfulness': 'No',
#   'diagnosis': 'Depression'},
#  {'age': 32,
#   'gender': 'Male',
#   'sleep_quality_index': 7.7,
#   'brain_fog_level': 1.7,
#   'physical_pain_score': 7.5,
#   'stress_level': 1.9,
#   'depression_phq9_score': 26.0,
#   'fatigue_severity_scale_score': 5.4,
#   'pem_duration_hours': 21.0,
#   'hours_of_sleep_per_night': 8.1,
#   'pem_present': 0,
#   'work_status': 'Partially working',
#   'social_activity_level': 'Very low',
#   'exercise_frequency': 'Rarely',
#   'meditation_or_mindfulness': 'Yes',
#   'diagnosis': 'Depression'}]

# %%
len(data)
# Out:
# 1000

# %%
DB_NAME = "DEPRESSION_DB"
COLLECTION_NAME = "data"
load_dotenv()
mongo_url=os.getenv("MONGO_URL")

# %%
client = pymongo.MongoClient(mongo_url, serverSelectionTimeoutMS=30000, socketTimeoutMS=30000)
data_base = client[DB_NAME]
collection=data_base[COLLECTION_NAME]
#use batch loading to insert the data into MongoDB because th dataset is large

BATCH_SIZE = 500
MAX_RETRIES = 3

for i in range(0, len(data), BATCH_SIZE):
    batch = data[i:i + BATCH_SIZE]
    for attempt in range(MAX_RETRIES):
        try:
            collection.insert_many(batch)
            break
        except AutoReconnect as e:
            print(f"Retrying batch insert ({i}-{i+BATCH_SIZE}) after error : {e}") 
            time.sleep(5)
    else:
        print(f"Failed to insert batch {i} - {i+BATCH_SIZE} after retries ")
